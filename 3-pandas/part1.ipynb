# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df[df["diagnosis"]=="B"]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19    8510426         B       13.540         14.36           87.46      566.3
# 20    8510653         B       13.080         15.71           85.63      520.0
# 21    8510824         B        9.504         12.44           60.34      273.9
# 37     854941         B       13.030         18.42           82.61      523.8
# 46   85713702         B        8.196         16.84           51.71      201.9
# ..        ...       ...          ...           ...             ...        ...
# 558    925277         B       14.590         22.68           96.39      657.1
# 559    925291         B       11.510         23.93           74.52      403.5
# 560    925292         B       14.050         27.15           91.38      600.4
# 561    925311         B       11.200         29.37           70.67      386.0
# 568     92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df["radius_mean"]
# Out:
# 0      17.99
# 1      20.57
# 2      19.69
# 3      11.42
# 4      20.29
#        ...
# 564    21.56
# 565    20.13
# 566    16.60
# 567    20.60
# 568     7.76
# Name: radius_mean, Length: 569, dtype: float64

# %%
len(df["texture_mean"])
# Out:
# 569

# %%
df[["diagnosis","radius_mean"]]
# Out:
#     diagnosis  radius_mean
# 0           M        17.99
# 1           M        20.57
# 2           M        19.69
# 3           M        11.42
# 4           M        20.29
# ..        ...          ...
# 564         M        21.56
# 565         M        20.13
# 566         M        16.60
# 567         M        20.60
# 568         B         7.76
#
# [569 rows x 2 columns]

# %%
df[["diagnosis","perimeter_mean"]]
# Out:
#     diagnosis  perimeter_mean
# 0           M          122.80
# 1           M          132.90
# 2           M          130.00
# 3           M           77.58
# 4           M          135.10
# ..        ...             ...
# 564         M          142.00
# 565         M          131.20
# 566         M          108.30
# 567         M          140.10
# 568         B           47.92
#
# [569 rows x 2 columns]

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.iloc[9] #obtains all data for patient in this row
# Out:
# id                         84501001
# diagnosis                         M
# radius_mean                   12.46
# texture_mean                  24.04
# perimeter_mean                83.97
# area_mean                     475.9
# smoothness_mean              0.1186
# compactness_mean             0.2396
# concavity_mean               0.2273
# concave points_mean         0.08543
# symmetry_mean                 0.203
# fractal_dimension_mean      0.08243
# radius_se                    0.2976
# texture_se                    1.599
# perimeter_se                  2.039
# area_se                       23.94
# smoothness_se              0.007149
# compactness_se              0.07217
# concavity_se                0.07743
# concave points_se           0.01432
# symmetry_se                 0.01789
# fractal_dimension_se        0.01008
# radius_worst                  15.09
# texture_worst                 40.68
# perimeter_worst               97.65
# area_worst                    711.4
# ...

# %%
list(df.iloc[10]) #to see any missing values in this row, iloc=data inspection
# Out:
# [np.int64(845636),
#  'M',
#  np.float64(16.02),
#  np.float64(23.24),
#  np.float64(102.7),
#  np.float64(797.8),
#  np.float64(0.08206),
#  np.float64(0.06669),
#  np.float64(0.03299),
#  np.float64(0.03323),
#  np.float64(0.1528),
#  np.float64(0.05697),
#  np.float64(0.3795),
#  np.float64(1.187),
#  np.float64(2.466),
#  np.float64(40.51),
#  np.float64(0.004029),
#  np.float64(0.009269),
#  np.float64(0.01101),
#  np.float64(0.007591),
#  np.float64(0.0146),
#  np.float64(0.003042),
#  np.float64(19.19),
#  np.float64(33.88),
#  np.float64(123.8),
#  np.float64(1150.0),
#  np.float64(0.1181),
#  np.float64(0.1551),
#  np.float64(0.1459),
#  np.float64(0.09975),
#  np.float64(0.2948),
#  np.float64(0.08452),
#  np.float64(nan)]

# %%
df.iloc[8]["diagnosis"]
# Out:
# 'M'

# %%
df.isna().sum() 
#df.isna(): converts df into true or false
#true=empty, false=not-empty
#adds up sum of how many missing values down each column
#unnamed 32: gives column index of empty column
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df[df.isna().any(axis=1)]
#any= atleast one true, use 1 for horizontal axis
#Show me rows where there is at least one missing value
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.isna().sum() 
#    id   diagnosis   radius   bad_column
# 0  1      M         10        NaN
# 1  2      B         12        NaN
# 2  3      M         15        NaN
#    id   diagnosis   radius   bad_column
# 0  F      F         F        T
# 1  F      F         F        T
# 2  F      F         F        T
# id           0
# diagnosis    0
# radius       0
# bad_column   3
# Count TRUEs per column
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df = df.drop(columns=["Unnamed: 32"]) #remove specific empty column

# %%
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df = df.dropna(axis=1, how='all') #removes any column thats completely empty
