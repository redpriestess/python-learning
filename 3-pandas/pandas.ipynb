# %%
import pandas as pd

df=pd.read_csv("new.csv")

df

# %%
df["Price"].value_counts()# df["Price"].mean()
# df["Price"].sum()
# df["Price"].idxmin()
# df["Price"].min()
# df["Price"].max()
# df["Price"].idxmax()
df["Price"].count()

# df["Quantity"].sum()
# len(df)
# Out:
# Price
# 300     2
# 1200    1
# 800     1
# 600     1
# 150     1
# 750     1
# 400     1
# 1300    1
# 850     1
# 500     1
# 120     1
# 900     1
# 650     1
# 350     1
# 450     1
# 1100    1
# 200     1
# 700     1
# 320     1
# Name: count, dtype: int64

# %%
df.groupby("Country")["Price"].mean()
df.groupby("Country")["Price"].sum()
df.groupby("Country")["Price"].mean().idxmax()
# df.groupby("Country")["Price"].min()
# df.groupby("Country")["Price"].mean().sort_values(ascending=False)
df.groupby("Country")["Price"].mean().idxmax()
df.groupby("Country")["Price"].mean().idxmin()
# Out:
# 'Brazil'

# %%
df[df["Category"]=="Electronics"].groupby("Country")["Price"].sum().idxmax()
# Out:
# 'Germany'

# %%
df.groupby("Category")["Price"].mean().idxmax()
df.groupby("Category")["Price"].sum().idxmin()
df.groupby("Country")["Quantity"].mean()
df.mean(numeric_only=True).idxmax()
# Out:
# 'Price'
